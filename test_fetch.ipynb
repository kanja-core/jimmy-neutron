# %%
from app.src.modules.graph.factory import BuilderFactory
from app.src.modules.node.types import NodePassInOutput

builder = BuilderFactory.test_fetch()
graph = builder.exec()
# Out:
# /Users/paulochade/Documents/projects/kanja/dev/main/engine/jimmy-neutron/env.nosync/lib/python3.12/site-packages/pydantic/_migration.py:283: UserWarning: `pydantic.generics:GenericModel` has been moved to `pydantic.BaseModel`.
#   warnings.warn(f'`{import_path}` has been moved to `{new_location}`.')

# %%
in_node: NodePassInOutput[str] = NodePassInOutput[str](data='15358587888')

# %%
await graph.ainvoke(in_node)
# Out:
# --------- NodePass ---------
# <class 'app.src.modules.node.types.NodePassInOutput[str]'>
# name: first
# input: {"data":"15358587888"}
# output: {"data":"15358587888"}
# --------- NodeMapper ---------
# name: map_start_fetch
# input: {"data":"15358587888"}
# output: {"params":{"cpf_cnpj":"15358587888"}}
# --------- NodeFetcher ---------
# name: fetch_lawsuits
# input: {"params":{"cpf_cnpj":"15358587888"}}
# ...
